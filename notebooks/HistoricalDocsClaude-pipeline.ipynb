# %%
# !pip install anthropic -q

import anthropic
import base64
import io
from pathlib import Path
from PIL import Image

def image_to_text(jpeg_path):
    client = anthropic.Anthropic(
        api_key="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",  # Use your API key
    )

    with Image.open(jpeg_path).convert('L') as image:
        # Convert image to PNG format in memory and then encode to base64
        buffered = io.BytesIO()
        image.save(buffered, format="PNG")
        base64_image = base64.b64encode(buffered.getvalue()).decode('utf-8')

    prompt_template = (
            "'instruction':'You are an expert in historical document recognition. "
            "Please transcribe the full document content directly from the input image. "
            "This is a treaty document from the 1700s, specifically the Treaty of Peace and Friendship between the United States and Morocco, signed on July 15, 1786. "
            "Please extract key details such as: "
            "1. Treaty Title, "
            "2. Date of Agreement, "
            "3. Parties Involved (United States and Morocco), "
            "4. Key clauses or terms from the treaty. "
            "Please provide the transcribed text and organize it into key components for better clarity.', \n"
            "'result':"
    )

    message = client.messages.create(
        model="claude-3-7-sonnet-20250219",
        max_tokens=1000,
        temperature=0.0,
        system="You are a useful AI file assistant, adept at analyzing images into text content.",
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "image",
                        "source": {
                            "type": "base64",
                            "media_type": "image/png",  
                            "data": base64_image
                        }
                    },
                    {
                        "type": "text",
                        "text": prompt_template
                    }
                ]
            }
        ]
    )

    return message.content
input_dir = Path('.') 

jpeg_path = input_dir / 'image1.jpg' 

try:
    output = image_to_text(jpeg_path)
    print("API Response:", output)
    if isinstance(output, list):
        extracted_texts = [block['text'] for block in output if 'text' in block]
        transcribed_text = "\n\n".join(extracted_texts) 
        transcribed_text = output

    print("\nTranscribed Text:")
    print(transcribed_text)

except Exception as e:
    print(f"Error processing {jpeg_path.name}: {str(e)}")

print("Done.")
# Out:
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# ...

# %%
# !pip install anthropic -q

import anthropic
import base64
import io
from pathlib import Path
from PIL import Image

def compress_image(jpeg_path, max_size_mb=5):
    with Image.open(jpeg_path) as img:

        img_byte_arr = io.BytesIO()
        img.save(img_byte_arr, format='JPEG', quality=50) 
        img_byte_arr.seek(0)
        
        while len(img_byte_arr.getvalue()) > max_size_mb * 1024 * 1024: 
    
            width, height = img.size
            img = img.resize((int(width * 0.7), int(height * 0.7))) 
            
            img_byte_arr = io.BytesIO()
            img.save(img_byte_arr, format='JPEG', quality=50) 
            img_byte_arr.seek(0)
        
        return img_byte_arr

def image_to_text(jpeg_path):
    client = anthropic.Anthropic(
        api_key="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",  # Use your API key
    )
    img_byte_arr = compress_image(jpeg_path)

    base64_image = base64.b64encode(img_byte_arr.getvalue()).decode('utf-8')
    prompt_template = (
            "'instruction':'You are an expert in historical document recognition. "
            "Please transcribe the full document content directly from the input image. "
            "This is a personal letter from Noah Warren, dated February 6, 1784. "
            "Please extract key details such as: "
            "1. Letter's Title or Subject, "
            "2. Date of the letter, "
            "3. Key phrases or names mentioned, "
            "4. Any significant details in the body of the letter. "
            "Please transcribe the text and highlight any important historical references.', \n"
            "'result':"
    )

    message = client.messages.create(
        model="claude-3-7-sonnet-20250219",  
        max_tokens=1000,
        temperature=0.0,
        system="You are a useful AI file assistant, adept at analyzing images into text content.",
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "image",
                        "source": {
                            "type": "base64",
                            "media_type": "image/jpeg",  
                            "data": base64_image
                        }
                    },
                    {
                        "type": "text",
                        "text": prompt_template
                    }
                ]
            }
        ]
    )

    return message.content 
input_dir = Path('.')  

jpeg_path = input_dir / 'image4.jpg' 

try:
    output = image_to_text(jpeg_path)

    print("API Response:", output)

    if isinstance(output, list):
        extracted_texts = [block['text'] for block in output if 'text' in block]
        transcribed_text = "\n\n".join(extracted_texts) 
    else:
        transcribed_text = output
    print("\nTranscribed Text:")
    print(transcribed_text)

except Exception as e:
    print(f"Error processing {jpeg_path.name}: {str(e)}")

print("Done.")
# Out:
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# ...
